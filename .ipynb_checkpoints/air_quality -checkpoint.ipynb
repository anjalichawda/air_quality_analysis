# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv', encoding='unicode_escape', low_memory=False)

# %%
cd=data.copy()

# %%
cd.head(10)
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0      150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1      151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2      152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3      150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4      151     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 5      152     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 6      150     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 7      151     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 8      152     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 9      151       May - M051990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# ...

# %% [markdown]
# # checking rows entries from the end

# %%
cd.tail(10)
# Out:
#        stn_code sampling_date                        state  location  \
# 435732     SAMP      09-12-15                  West Bengal  ULUBERIA
# 435733     SAMP      12-12-15                  West Bengal  ULUBERIA
# 435734     SAMP      15-12-15                  West Bengal  ULUBERIA
# 435735     SAMP      18-12-15                  West Bengal  ULUBERIA
# 435736     SAMP      21-12-15                  West Bengal  ULUBERIA
# 435737     SAMP      24-12-15                  West Bengal  ULUBERIA
# 435738     SAMP      29-12-15                  West Bengal  ULUBERIA
# 435739      NaN           NaN  andaman-and-nicobar-islands       NaN
# 435740      NaN           NaN                  Lakshadweep       NaN
# 435741      NaN           NaN                      Tripura       NaN
#
#                                            agency   type   so2   no2   rspm  \
# 435732  West Bengal State Pollution Control Board  RIRUO  22.0  50.0  145.0
# ...

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
cd.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
cd.shape
# Out:
# (435742, 13)

# %%
cd['date'] = pd.to_datetime(cd['date'], format='%Y-%m-%d', errors='coerce')
cd.head(12)
# Out:
#    stn_code       sampling_date           state   location agency  \
# 0       150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1       151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2       152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3       150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4       151     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 5       152     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 6       150     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 7       151     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 8       152     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 9       151       May - M051990  Andhra Pradesh  Hyderabad    NaN
# 10      152       May - M051990  Andhra Pradesh  Hyderabad    NaN
# 11      150      June - M061990  Andhra Pradesh  Hyderabad    NaN
#
#                                   type  so2   no2  rspm    spm  \
# ...

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
agency_counts = cd['agency'].value_counts()
print(agency_counts)
# Out:
# agency
# Maharashtra State Pollution Control Board                                 27857
# Uttar Pradesh State Pollution Control Board                               22686
# Andhra Pradesh State Pollution Control Board                              19139
# Himachal Pradesh State Environment Proection & Pollution Control Board    15287
# Punjab State Pollution Control Board                                      15232
#                                                                           ...
# Arunachal Pradesh State Pollution Control Board                              90
# TNPC                                                                         82
# RPCB                                                                         63
# VRCE                                                                         61
# RJPB                                                                         53
# Name: count, Length: 64, dtype: int64

# %%
type_count=cd["type"].value_counts()
print(type_count)
# Out:
# type
# Residential, Rural and other Areas    179014
# Industrial Area                        96091
# Residential and others                 86791
# Industrial Areas                       51747
# Sensitive Area                          8980
# Sensitive Areas                         5536
# RIRUO                                   1304
# Sensitive                                495
# Industrial                               233
# Residential                              158
# Name: count, dtype: int64

# %%
cd=cd.dropna(axis=0,subset=['type'])
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 430349 entries, 0 to 435738
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     286275 non-null  object
#  1   sampling_date                430349 non-null  object
#  2   state                        430349 non-null  object
#  3   location                     430349 non-null  object
#  4   agency                       280871 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          396161 non-null  float64
#  7   no2                          414501 non-null  float64
#  8   rspm                         395319 non-null  float64
#  9   spm                          193601 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
# Check if 'type' column has any NaNs left
print(data['type'].isnull().sum())
# Out:
# 5393

# %%
print(cd['type'].isnull().sum())
# Out:
# 0

# %%
data.shape
# Out:
# (435742, 13)

# %%
cd
# Out:
#        stn_code       sampling_date           state   location  \
# 0           150  February - M021990  Andhra Pradesh  Hyderabad
# 1           151  February - M021990  Andhra Pradesh  Hyderabad
# 2           152  February - M021990  Andhra Pradesh  Hyderabad
# 3           150     March - M031990  Andhra Pradesh  Hyderabad
# 4           151     March - M031990  Andhra Pradesh  Hyderabad
# ...         ...                 ...             ...        ...
# 435734     SAMP            15-12-15     West Bengal   ULUBERIA
# 435735     SAMP            18-12-15     West Bengal   ULUBERIA
# 435736     SAMP            21-12-15     West Bengal   ULUBERIA
# 435737     SAMP            24-12-15     West Bengal   ULUBERIA
# 435738     SAMP            29-12-15     West Bengal   ULUBERIA
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# ...

# %%
print(cd["location"].isnull().sum())
# Out:
# 0

# %%
print(cd["so2"].isnull().sum())
# Out:
# 34188

# %%
cd=cd.dropna(axis=0,subset=["so2"])

# %%
print(cd["so2"].isnull().sum())
# Out:
# 0

# %%
print(cd["no2"].isnull().sum())
# Out:
# 1981

# %%
cd=cd.dropna(axis=0,subset=["no2"])

# %%
print(cd["no2"].isnull().sum())
# Out:
# 0

# %%
print(cd["rspm"].isnull().sum())
# Out:
# 29345

# %%
cd=cd.dropna(axis=0,subset=["rspm"])

# %%
print(cd["rspm"].isnull().sum())
# Out:
# 0

# %%
print(cd["spm"].isnull().sum())
# Out:
# 223103

# %%
cd=cd.dropna(axis=0,subset=["spm"])

# %%
print(cd["spm"].isnull().sum())
# Out:
# 0

# %%
print(cd['pm2_5'].isnull().sum())
# Out:
# 141732

# %%
cd=cd.dropna(axis=0,subset=['pm2_5'])

# %%
print(cd['pm2_5'].isnull().sum())
# Out:
# 0

# %% [markdown]
# # feilds which doesn't require

# %%
del cd['agency']
del cd['location_monitoring_station']
del cd['stn_code']
del cd['sampling_date']

# %%
cd.head(10)
# Out:
# Empty DataFrame
# Columns: [state, location, type, so2, no2, rspm, spm, pm2_5, date]
# Index: []
